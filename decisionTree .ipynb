# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('split_df.csv')
df.head()
# Out:
#                       Table 1  Spectacles  Age  Gender        Name   id  Eye  \
# 0  زرق أيمن تم معالجته جراحيا         0.0   64       0  شاهين ميرو  1.0    0
# 1  زرق أيمن تم معالجته جراحيا         0.0   64       0  شاهين ميرو  1.0    1
# 2                   زرق متقدم         1.0   62       0  أيمن سمارة  2.0    0
# 3                   زرق متقدم         1.0   62       0  أيمن سمارة  2.0    1
# 4                 لا يوجد زرق         0.0   48       1   رندة ناصر  3.0    0
#
#     VA  CDR  Diagnosis   IOP
# 0  0.6  0.5          0  14.0
# 1  0.7  0.9          1  23.0
# 2  NaN  NaN          1  25.0
# 3  9.0  0.8          1  40.0
# 4  1.0  0.5          0  15.0

# %%
dfClean = df.dropna()

# %%
xData = df_without_column = dfClean.drop(columns=['Diagnosis','Table 1','Name'])
xData
# Out:
#     Spectacles  Age  Gender    id  Eye   VA  CDR   IOP
# 0          0.0   64       0   1.0    0  0.6  0.5  14.0
# 1          0.0   64       0   1.0    1  0.7  0.9  23.0
# 3          1.0   62       0   2.0    1  9.0  0.8  40.0
# 4          0.0   48       1   3.0    0  1.0  0.5  15.0
# 5          0.0   48       1   3.0    1  1.0  0.4  14.0
# ..         ...  ...     ...   ...  ...  ...  ...   ...
# 84         1.0   55       1  43.0    0  0.2  0.8  10.0
# 86         0.0   71       0  44.0    0  0.3  0.5  15.0
# 87         0.0   71       0  44.0    1  0.6  0.7  16.0
# 88         1.0   65       0  45.0    0  0.5  0.3  15.0
# 89         1.0   65       0  45.0    1  0.2  0.3  12.0
#
# [68 rows x 8 columns]

# %%
yData = dfClean['Diagnosis']
yData
# Out:
# 0     0
# 1     1
# 3     1
# 4     0
# 5     0
#      ..
# 84    1
# 86    1
# 87    1
# 88    0
# 89    0
# Name: Diagnosis, Length: 68, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(xData, yData, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#     Spectacles  Age  Gender    id  Eye    VA   CDR   IOP
# 75         1.0   62       1  38.0    1  1.00   0.6  16.0
# 76         0.0   67       1  39.0    0  0.05   0.3   9.0
# 65         0.0   45       1  33.0    1  9.00   0.9  27.0
# 10         1.0   65       1   6.0    0  0.40   0.9  25.0
# 56         1.0   44       0  29.0    0  1.00   0.7  11.0
# 38         1.0   24       1  20.0    0  0.50   0.6  14.0
# 46         1.0   12       1  24.0    0  1.00   0.5  12.0
# 24         0.0   68       1  13.0    0  0.60   0.8  11.0
# 59         1.0   73       0  30.0    1  0.80   0.3  11.0
# 43         0.0   55       0  22.0    1  0.90   0.3  21.0
# 64         0.0   45       1  33.0    0  1.00   0.9  22.0
# 37         1.0   64       1  19.0    1  1.00   0.5  19.0
# 16         1.0   25       1   9.0    0  1.00   0.4  13.0
# 84         1.0   55       1  43.0    0  0.20   0.8  10.0
# 52         0.0   43       1  27.0    0  1.00   0.3  18.0
# 4          0.0   48       1   3.0    0  1.00   0.5  15.0
# 20         1.0   76       0  11.0    0  0.10   0.8  44.0
# 44         0.0   66       0  23.0    0  9.00   0.9  13.0
# 11         1.0   65       1   6.0    1  0.90   0.8  10.0
# 58         1.0   73       0  30.0    0  0.50   0.8  20.0
# 7          1.0   60       0   4.0    1  0.10   0.7  14.0
# 77         0.0   67       1  39.0    1  0.05   0.8  12.0
# 88         1.0   65       0  45.0    0  0.50   0.3  15.0
# 18         0.0   64       1  10.0    0  0.50   0.3  36.0
# 34         0.0   53       1  18.0    0  0.80   0.4  14.0
# 33         1.0   56       0  17.0    1  1.00   0.7  10.0
# 31         0.0   39       1  16.0    1  1.00   0.8  10.0
# 89         1.0   65       0  45.0    1  0.20   0.3  12.0
# 14         0.0   50       0   8.0    0  1.00   0.8  14.0
# 39         1.0   24       1  20.0    1  0.50   0.6  17.0
# 86         0.0   71       0  44.0    0  0.30   0.5  15.0
# 68         1.0   52       1  35.0    0  0.50   0.9  20.0
# 47         1.0   12       1  24.0    1  1.00   0.7   8.0
# 36         1.0   64       1  19.0    0  0.90   0.8  24.0
# 57         1.0   44       0  29.0    1  1.00   0.7  12.0
# 74         1.0   62       1  38.0    0  0.40   0.8  23.0
# 1          0.0   64       0   1.0    1  0.70   0.9  23.0
# 26         0.0   64       0  14.0    0  0.50   0.7  18.0
# 3          1.0   62       0   2.0    1  9.00   0.8  40.0
# 83         0.0   67       1  42.0    1  0.50   0.3  17.0
# 49         0.0   64       0  25.0    1  0.80   0.3  14.0
# 45         0.0   66       0  23.0    1  0.10   0.9  11.0
# 71         0.0   73       1  36.0    1  0.20   0.4  40.0
# 30         0.0   39       1  16.0    0  1.00   0.3  16.0
# 80         0.0   29       0  41.0    0  0.70   0.8  13.0
# 13         0.0   70       1   7.0    1  0.90   0.3  16.0
# 27         0.0   64       0  14.0    1  0.40   0.5  22.0
# 21         1.0   76       0  11.0    1  0.20  10.0  33.0
# 78         1.0   17       0  40.0    0  0.40   0.9  48.0
# 48         0.0   64       0  25.0    0  0.30   0.7  23.0
# 25         0.0   68       1  13.0    1  0.10   0.8  34.0
# 81         0.0   29       0  41.0    1  9.00   0.8  16.0
# 17         1.0   25       1   9.0    1  0.70   0.8  19.0
# 69         1.0   52       1  35.0    1  0.80   0.9  21.0

# %%
X_test
# Out:
#     Spectacles  Age  Gender    id  Eye   VA  CDR   IOP
# 60         0.0   25       1  31.0    0  1.0  0.3  14.0
# 19         0.0   64       1  10.0    1  0.7  0.3  17.0
# 5          0.0   48       1   3.0    1  1.0  0.4  14.0
# 12         0.0   70       1   7.0    0  0.6  0.9  42.0
# 35         0.0   53       1  18.0    1  0.8  0.7  15.0
# 53         0.0   43       1  27.0    1  1.0  0.3  19.0
# 79         1.0   17       0  40.0    1  9.0  0.9  50.0
# 6          1.0   60       0   4.0    0  0.2  0.7  10.0
# 82         0.0   67       1  42.0    0  0.4  0.3  18.0
# 15         0.0   50       0   8.0    1  0.9  0.7  16.0
# 32         1.0   56       0  17.0    0  1.0  0.7  11.0
# 87         0.0   71       0  44.0    1  0.6  0.7  16.0
# 61         0.0   25       1  31.0    1  1.0  0.3  16.0
# 0          0.0   64       0   1.0    0  0.6  0.5  14.0

# %%
decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn import tree
tree.plot_tree(decision_tree)
# Out:
# [Text(0.6071428571428571, 0.9285714285714286, 'x[7] <= 19.5\ngini = 0.475\nsamples = 54\nvalue = [21, 33]'),
#  Text(0.35714285714285715, 0.7857142857142857, 'x[6] <= 0.35\ngini = 0.49\nsamples = 35\nvalue = [20, 15]'),
#  Text(0.21428571428571427, 0.6428571428571429, 'x[3] <= 26.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.14285714285714285, 0.5, 'x[5] <= 0.85\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07142857142857142, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21428571428571427, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5, 0.6428571428571429, 'x[5] <= 0.4\ngini = 0.497\nsamples = 26\nvalue = [12, 14]'),
#  Text(0.42857142857142855, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5714285714285714, 0.5, 'x[1] <= 41.5\ngini = 0.49\nsamples = 21\nvalue = [12, 9]'),
#  Text(0.42857142857142855, 0.35714285714285715, 'x[5] <= 0.85\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.35714285714285715, 0.21428571428571427, 'x[3] <= 14.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2857142857142857, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42857142857142855, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7142857142857143, 0.35714285714285715, 'x[0] <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.6428571428571429, 0.21428571428571427, 'x[3] <= 13.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5714285714285714, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7142857142857143, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7857142857142857, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8571428571428571, 0.7857142857142857, 'x[6] <= 0.35\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.7857142857142857, 0.6428571428571429, 'x[3] <= 16.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7142857142857143, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8571428571428571, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9285714285714286, 0.6428571428571429, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]')]

# %%
y_pred = decision_tree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")


print("\nClassification Report:")
print(classification_report(y_test, y_pred))


print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.93
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94         9
#            1       0.83      1.00      0.91         5
#
#     accuracy                           0.93        14
#    macro avg       0.92      0.94      0.93        14
# weighted avg       0.94      0.93      0.93        14
#
#
# Confusion Matrix:
# [[8 1]
#  [0 5]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
