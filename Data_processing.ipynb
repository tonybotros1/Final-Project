# %%
# Importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import median_absolute_error
from sklearn.datasets import fetch_openml
from sklearn.impute import SimpleImputer
import pandas as pd
import re
# Loading the Boston housing dataset
# housing = fetch_openml(name="house_prices", as_frame=True)

# %%
# df = pd.read_excel('data .xlsx')

# # حفظ البيانات في ملف CSV مع الترميز المناسب
# df.to_csv('data_with_arabic.csv', encoding='utf-8-sig', index=False)

# %%
data =  pd.read_csv('data_with_arabic.csv',encoding='utf-8-sig')
# data=data.drop_duplicates()
# df = pd.DataFrame(data)
# df.to_csv("data_new.csv", index=False)

# %%
data
# Out:
#                                               Table 1  CDR(OD)  CDR(OS)  \
# 0                          زرق أيمن تم معالجته جراحيا      0.9      0.5
# 1                                           زرق متقدم      0.8      NaN
# 2                                         لا يوجد زرق      0.4      0.5
# 3                               زرق مزدوج أشد بالأيمن      0.7      0.7
# 4                           زرق بالعينتين أشد بالأيمن      NaN      NaN
# 5                           زرق أيسر وتم علاجه جراحيا      0.8      0.9
# 6                                            زرق أيسر      0.3  0.8-0.9
# 7                                       مريض غير زرقي      0.7      0.8
# 8                           زرق بالعينتين أشد بالأيمن      0.8      0.4
# 9                                            زرق أيسر      0.3      0.3
# 10                                    زرقي وبالعينتين       10      0.8
# 11                             مريض زرقي مضبوط دوائيا      NaN      NaN
# 12  مريضة زرقية، أذية زرقية بالأيمن وتم معالجتها ج...      0.8  0.7-0.8
# 13                          زرق بالعينتين أشد بالأيسر      0.5  0.6-0.7
# 14                          زرق مزدوج متقدم غير مضبوط      NaN      NaN
# 15                                           زرق أيمن      0.8      0.3
# 16                                     طبيعي ليس زرقي      0.7      0.7
# 17                                              زرقية      0.7      0.4
# 18                                           زرق أيسر      0.5      0.8
# 19                  طبيعي لا يوجد زرق، تقعر فيزيولوجي      0.6      0.6
# 20                                  طبيعي لا يوجد زرق      0.3      0.3
# 21                                  طبيعي لا يوجد زرق      0.3      0.3
# 22                                          زرق مزدوج      0.9      0.9
# 23        زرقية ولكن لا يوجد مصداقية ل OCT بسبب العمر  0.6-0.7      0.5
# 24                                          مريض زرقي      0.3      0.7
# 25                                        لا يوجد زرق      0.3      0.3
# 26                                        لا يوجد زرق      0.3      0.3
# 27                                   زرق مغلق الزاوية      0.3      0.3
# 28                                        لا يوجد زرق      0.7      0.7
# 29                                           زرق أيسر      0.3      0.8
# 30                                        لا يوجد زرق      0.3      0.3
# 31                                           لا زرقية      NaN      NaN
# 32                                          زرق مزدوج      0.9      0.9
# 33                                        لا يوجد زرق      NaN      NaN
# 34                                        مريضة زرقية      0.9      0.9
# 35  ارتفاع ضغط عين يمنى بسبب الزرق من النوع الوعائ...      0.4      NaN
# 36                         زرق أيمن تم معالجته جراحيا      NaN      NaN
# 37                   زرق أيسر متقدم تم معالجته جراحيا      0.6      0.8
# 38                                           زرق أيمن      0.8      0.3
# 39                                          زرق مزدوج      0.9      0.9
# 40                                           زرق أيمن  0.7-0.8      0.8
# 41                                        لا يوجد زرق      0.3      0.3
# 42                         زرق أيسر تم معالجته جراحيا      NaN      0.8
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...      0.7      0.5
# 44                                        لا يوجد زرق      0.3      0.3
#
#     IOP(OD)  IOP(OS)         VA(OD)         VA(OS) Spectacles  Age Gender  \
# 0      23.0     14.0            0.7            0.6    لا يوجد   64    ذكر
# 1      40.0     25.0       Cf 0.5 m            NaN       يوجد   62    ذكر
# 2      14.0     15.0             10             10    لا يوجد   48   أنثى
# 3      14.0     10.0            0.1            0.2       يوجد   60    ذكر
# 4      11.0      8.0             10            0.5       يوجد   58   أنثى
# 5      10.0     25.0            0.9            0.4       يوجد   65   أنثى
# 6      16.0     42.0            0.9            0.6    لا يوجد   70   أنثى
# 7      16.0     14.0            0.9             10    لا يوجد   50    ذكر
# 8      19.0     13.0            0.7             10       يوجد   25   أنثى
# 9      17.0     36.0            0.7            0.5    لا يوجد   64   أنثى
# 10     33.0     44.0            0.2            0.1       يوجد   76    ذكر
# 11     12.0     17.0              1            0.7    لا يوجد   61    ذكر
# 12     34.0     11.0            0.1            0.6    لا يوجد   68   أنثى
# 13     22.0     18.0            0.4            0.5    لا يوجد   64    ذكر
# 14     35.0     40.0             HM  أمام العين cf       يوجد   65    ذكر
# 15     10.0     16.0             10             10    لا يوجد   39   أنثى
# 16     10.0     11.0             10             10       يوجد   56    ذكر
# 17     15.0     14.0            0.8            0.8    لا يوجد   53   أنثى
# 18     19.0     24.0             10        0.8-0.9       يوجد   64   أنثى
# 19     17.0     14.0            0.5            0.5       يوجد   24   أنثى
# 20     12.0     12.0            NaN            NaN    لا يوجد   70    ذكر
# 21     21.0     20.0            0.9            NaN    لا يوجد   55    ذكر
# 22     11.0     13.0            0.1         cf 2 m    لا يوجد   66    ذكر
# 23      8.0     12.0             10             10       يوجد   12   أنثى
# 24     14.0     23.0            0.8            0.3    لا يوجد   64    ذكر
# 25      NaN      NaN            0.9            0.5    لا يوجد   69   أنثى
# 26     19.0     18.0             10             10    لا يوجد   43   أنثى
# 27     34.0     14.0             10             10    لا يوجد   59   أنثى
# 28     12.0     11.0             10             10       يوجد   44    ذكر
# 29     11.0     20.0            0.8            0.5       يوجد   73    ذكر
# 30     16.0     14.0             10             10    لا يوجد   25   أنثى
# 31     18.0     18.0         cf 2 m             10    لا يوجد   58   أنثى
# 32     27.0     22.0  أمام العين cf             10    لا يوجد   45   أنثى
# 33     12.0     12.0             10             10    لا يوجد   32    ذكر
# 34     21.0     20.0            0.8            0.5       يوجد   52   أنثى
# 35     40.0     12.0            0.2            0.5    لا يوجد   73   أنثى
# 36     15.0     16.0            0.4            0.7    لا يوجد   37    ذكر
# 37     16.0     23.0             10            0.4       يوجد   62   أنثى
# 38     12.0      9.0           0.05           0.05    لا يوجد   67   أنثى
# 39     50.0     48.0             HM            0.4       يوجد   17    ذكر
# 40     16.0     13.0             HM            0.7    لا يوجد   29    ذكر
# 41     17.0     18.0            0.5            0.4    لا يوجد   67   أنثى
# 42      NaN     10.0            NaN            0.2       يوجد   55   أنثى
# 43     16.0     15.0            0.6        0.2-0.3    لا يوجد   71    ذكر
# 44     12.0     15.0            0.2        0.4-0.5       يوجد   65    ذكر
#
#                  Name    id  Diagnosis(OD)  Diagnosis(OS)
# 0          شاهين ميرو   1.0              1              0
# 1          أيمن سمارة   2.0              1              1
# 2           رندة ناصر   3.0              0              0
# 3       مصطفى ملا علي   4.0              1              1
# 4       نهلة أبو قورة   5.0              1              1
# 5       لطيفة إبراهيم   6.0              0              1
# 6         فاطمة فرحان   7.0              0              1
# 7        صبحي الوزان    8.0              0              0
# 8            هبة لولو   9.0              1              1
# 9           خديجة كبة  10.0              0              1
# 10  عبدالرزاق بويضاني  11.0              1              1
# 11          أحمد طحان  12.0              1              1
# 12         حليمة شيخو  13.0              1              0
# 13         علي الحسين  14.0              1              1
# 14    محي الدين خاشوق  15.0              1              1
# 15         دلال محمود  16.0              1              0
# 16          نضال جريج  17.0              0              0
# 17        فاطمة الخلف  18.0              1              1
# 18        نجاح النهار  19.0              0              1
# 19         مروة محجوب  20.0              0              0
# 20        زهير الملاح  21.0              0              0
# 21         باسل الباش  22.0              0              0
# 22        نزار الحلو   23.0              1              1
# 23          ولاء حماد  24.0              1              1
# 24        حسين الحلقي  25.0              1              1
# 25          حصة الحمد  26.0              0              0
# 26       ايمان الزعبي  27.0              0              0
# 27    سلفانة أبو عسلي  28.0              1              1
# 28          وسام كاشي  29.0              0              0
# 29        صالح الهزاع  30.0              0              1
# 30       راما نصرالله  31.0              0              0
# 31        أسرار صنوبر  32.0              0              0
# 32     حنان الابراهيم  33.0              1              1
# 33   عبدالله الغزولي   34.0              1              0
# 34       نور عبدالله   35.0              1              1
# 35         جميلة عبيد  36.0              1              0
# 36     عبدالرحيم حماد  37.0              1              0
# 37         جانيت ضاهر  38.0              0              1
# 38          فاطمة عوض  39.0              1              0
# 39        حسن القاموع  40.0              1              1
# 40          محمد هلال  41.0              1              0
# 41        عنود الحميد  42.0              0              0
# 42       زريفة المحمد  43.0              0              1
# 43          هيثم قزاز  44.0              1              1
# 44          حمود غشام  45.0              0              0

# %%
# Create a new DataFrame to store the split rows
split_rows = []

# Iterate through each row of the original DataFrame
for index, row in data.iterrows():
    # Create a copy of the row for the left eye (OS)
    os_row = row.copy()
    os_row['Eye'] = 'OS'  # Left Eye
    os_row['VA'] = row['VA(OS)']
    os_row['CDR'] = row['CDR(OS)']
    os_row['Diagnosis'] = row['Diagnosis(OS)']
    os_row['IOP'] = row['IOP(OS)']
    split_rows.append(os_row)
    
    # Create a copy of the row for the right eye (OD)
    od_row = row.copy()
    od_row['Eye'] = 'OD'  # Right Eye
    od_row['VA'] = row['VA(OD)']
    od_row['CDR'] = row['CDR(OD)']
    od_row['Diagnosis'] = row['Diagnosis(OD)']
    od_row['IOP'] = row['IOP(OD)']
    split_rows.append(od_row)

# Create a new DataFrame from the split rows
split_df = pd.DataFrame(split_rows)

# Drop the unnecessary columns
split_df.drop(columns=['VA(OS)', 'VA(OD)', 'CDR(OS)', 'CDR(OD)', 'Diagnosis(OS)', 'Diagnosis(OD)', 'IOP(OS)', 'IOP(OD)'], inplace=True)

# Display the new DataFrame
print(split_df)
# Out:
#                                               Table 1 Spectacles  Age Gender  \
# 0                          زرق أيمن تم معالجته جراحيا    لا يوجد   64    ذكر
# 0                          زرق أيمن تم معالجته جراحيا    لا يوجد   64    ذكر
# 1                                           زرق متقدم       يوجد   62    ذكر
# 1                                           زرق متقدم       يوجد   62    ذكر
# 2                                         لا يوجد زرق    لا يوجد   48   أنثى
# ..                                                ...        ...  ...    ...
# 42                         زرق أيسر تم معالجته جراحيا       يوجد   55   أنثى
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...    لا يوجد   71    ذكر
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...    لا يوجد   71    ذكر
# 44                                        لا يوجد زرق       يوجد   65    ذكر
# 44                                        لا يوجد زرق       يوجد   65    ذكر
#
#             Name    id Eye        VA  CDR  Diagnosis   IOP
# 0     شاهين ميرو   1.0  OS       0.6  0.5          0  14.0
# 0     شاهين ميرو   1.0  OD       0.7  0.9          1  23.0
# 1     أيمن سمارة   2.0  OS       NaN  NaN          1  25.0
# 1     أيمن سمارة   2.0  OD  Cf 0.5 m  0.8          1  40.0
# 2      رندة ناصر   3.0  OS        10  0.5          0  15.0
# ..           ...   ...  ..       ...  ...        ...   ...
# 42  زريفة المحمد  43.0  OD       NaN  NaN          0   NaN
# 43     هيثم قزاز  44.0  OS   0.2-0.3  0.5          1  15.0
# 43     هيثم قزاز  44.0  OD       0.6  0.7          1  16.0
# 44     حمود غشام  45.0  OS   0.4-0.5  0.3          0  15.0
# 44     حمود غشام  45.0  OD       0.2  0.3          0  12.0
#
# [90 rows x 11 columns]

# %%
split_df
# Out:
#                                               Table 1 Spectacles  Age Gender  \
# 0                          زرق أيمن تم معالجته جراحيا    لا يوجد   64    ذكر
# 0                          زرق أيمن تم معالجته جراحيا    لا يوجد   64    ذكر
# 1                                           زرق متقدم       يوجد   62    ذكر
# 1                                           زرق متقدم       يوجد   62    ذكر
# 2                                         لا يوجد زرق    لا يوجد   48   أنثى
# ..                                                ...        ...  ...    ...
# 42                         زرق أيسر تم معالجته جراحيا       يوجد   55   أنثى
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...    لا يوجد   71    ذكر
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...    لا يوجد   71    ذكر
# 44                                        لا يوجد زرق       يوجد   65    ذكر
# 44                                        لا يوجد زرق       يوجد   65    ذكر
#
#             Name    id Eye        VA  CDR  Diagnosis   IOP
# 0     شاهين ميرو   1.0  OS       0.6  0.5          0  14.0
# 0     شاهين ميرو   1.0  OD       0.7  0.9          1  23.0
# 1     أيمن سمارة   2.0  OS       NaN  NaN          1  25.0
# 1     أيمن سمارة   2.0  OD  Cf 0.5 m  0.8          1  40.0
# 2      رندة ناصر   3.0  OS        10  0.5          0  15.0
# ..           ...   ...  ..       ...  ...        ...   ...
# 42  زريفة المحمد  43.0  OD       NaN  NaN          0   NaN
# 43     هيثم قزاز  44.0  OS   0.2-0.3  0.5          1  15.0
# 43     هيثم قزاز  44.0  OD       0.6  0.7          1  16.0
# 44     حمود غشام  45.0  OS   0.4-0.5  0.3          0  15.0
# 44     حمود غشام  45.0  OD       0.2  0.3          0  12.0
#
# [90 rows x 11 columns]

# %%
gender_mapping = {'ذكر': 0 , 'أنثى': 1}
split_df['Gender'] = split_df['Gender'].map(gender_mapping)

eye_mapping = {'OS': 0, 'OD': 1}
split_df['Eye'] = split_df['Eye'].map(eye_mapping)

eye_mapping = {'لا يوجد': 0, 'يوجد': 1}
split_df['Spectacles'] = split_df['Spectacles'].map(eye_mapping)

# %%
cf_array = []
for i in range(len(split_df['VA'])):
    # Check if the value is a string and if it contains 'cf' or 'HM' (case-insensitive)
    if isinstance(split_df['VA'].iloc[i], str) and ('cf' in split_df['VA'].iloc[i].lower() or 'HM' in split_df['VA'].iloc[i]):
        print(split_df['VA'].iloc[i])
        cf_array.append(split_df['VA'].iloc[i])
# Out:
# Cf 0.5 m
# أمام العين cf
# HM
# cf 2 m
# cf 2 m
# أمام العين cf
# HM
# HM

# %%
for i in range(len(split_df['VA'])):
    for j in range(len(cf_array)):
        if split_df['VA'].iloc[i] == cf_array[j]:
            split_df['VA'].iloc[i] = 9
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1394833798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 9

# %%
for i in range(len(split_df['VA'])):
    if split_df['VA'].iloc[i] == '10':
        # print(split_df['VA'].iloc[i])
        split_df['VA'].iloc[i] = 1.0
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1274017944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = 1.0

# %%
def get_bigger_number(phrase):
    numbers = re.findall(r'\d+\.\d+', phrase)  # Match any decimal number
    if len(numbers) == 2:  # If two numbers are found (as in the pattern 0.4-0.5)
        bigger_number = max(map(float, numbers))  # Convert numbers to float and get the maximum
        return bigger_number

# %%
for i in range(len(split_df['VA'])):
    if isinstance(split_df['VA'].iloc[i], str) and '-' in split_df['VA'].iloc[i]:
        bigger_number = get_bigger_number(split_df['VA'].iloc[i])
        split_df['VA'].iloc[i] = bigger_number
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1983676122.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = bigger_number
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1983676122.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = bigger_number
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1983676122.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['VA'].iloc[i] = bigger_number

# %%
for i in range(len(split_df['CDR'])):
    if isinstance(split_df['CDR'].iloc[i], str) and '-' in split_df['CDR'].iloc[i]:
        bigger_number = get_bigger_number(split_df['CDR'].iloc[i])
        split_df['CDR'].iloc[i] = bigger_number
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1389035994.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['CDR'].iloc[i] = bigger_number
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1389035994.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['CDR'].iloc[i] = bigger_number
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1389035994.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['CDR'].iloc[i] = bigger_number
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1389035994.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['CDR'].iloc[i] = bigger_number
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24828\1389035994.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_df['CDR'].iloc[i] = bigger_number

# %%
split_df
# Out:
#                                               Table 1  Spectacles  Age  \
# 0                          زرق أيمن تم معالجته جراحيا         0.0   64
# 0                          زرق أيمن تم معالجته جراحيا         0.0   64
# 1                                           زرق متقدم         1.0   62
# 1                                           زرق متقدم         1.0   62
# 2                                         لا يوجد زرق         0.0   48
# ..                                                ...         ...  ...
# 42                         زرق أيسر تم معالجته جراحيا         1.0   55
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...         0.0   71
# 43  مريض زرقي ثانوي بعد استخراج ساد لا يوجد اصابة ...         0.0   71
# 44                                        لا يوجد زرق         1.0   65
# 44                                        لا يوجد زرق         1.0   65
#
#     Gender          Name    id  Eye   VA  CDR  Diagnosis   IOP
# 0        0    شاهين ميرو   1.0    0  0.6  0.5          0  14.0
# 0        0    شاهين ميرو   1.0    1  0.7  0.9          1  23.0
# 1        0    أيمن سمارة   2.0    0  NaN  NaN          1  25.0
# 1        0    أيمن سمارة   2.0    1    9  0.8          1  40.0
# 2        1     رندة ناصر   3.0    0  1.0  0.5          0  15.0
# ..     ...           ...   ...  ...  ...  ...        ...   ...
# 42       1  زريفة المحمد  43.0    1  NaN  NaN          0   NaN
# 43       0     هيثم قزاز  44.0    0  0.3  0.5          1  15.0
# 43       0     هيثم قزاز  44.0    1  0.6  0.7          1  16.0
# 44       0     حمود غشام  45.0    0  0.5  0.3          0  15.0
# 44       0     حمود غشام  45.0    1  0.2  0.3          0  12.0
#
# [90 rows x 11 columns]

# %%
df = pd.DataFrame(split_df)
df.to_csv("split_df.csv", index=False)
